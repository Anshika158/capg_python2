# %%
import pandas as pd
from sklearn import datasets
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

from sklearn.metrics import r2_score , mean_squared_error , mean_absolute_error 

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
import datetime
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Melbourne.csv')

# %%
df.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             5151
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          4481
# Bathroom          4484
# Car               4626
# Landsize          6137
# BuildingArea     13529
# YearBuilt        12007
# CouncilArea       7891
# Lattitude         4304
# Longtitude        4304
# Regionname           1
# Propertycount        1
# dtype: int64

# %%
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')
corr = df.corr(numeric_only=True)
corr_price = corr[['Price']].sort_values(by='Price', ascending=False)
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,10))
sns.heatmap(corr_price, annot=True, cmap='coolwarm')
plt.title("Correlation with Price")
plt.show()

# %%
plt.show()

# %%
pd.options.display.float_format = '{:.0f}'.format
me=df['Price'].mean()

# %%
df['Price'].fillna(me , inplace=True)

# %%
df

# %%
pd.options.display.float_format = '{:.0f}'.format
dme=df['Distance'].mean()
df['Distance'].fillna(dme, inplace=True)
df

# %%
df

# %%
pme=df['Postcode'].mean()
df['Postcode'].fillna(pme, inplace=True)
df

# %%
property_me=df['Propertycount'].mean()
df['Propertycount'].fillna(property_me, inplace=True)
df

# %%
df.isna().sum()

# %%
region=df['Regionname'].mode()[0]
df['Regionname'].fillna(region, inplace=True)
df

# %%
df.isna().sum()

# %%
bed2=df['Bedroom2'].mean()
df['Bedroom2'].fillna(bed2, inplace=True)
df

# %%
br=df['Bathroom'].mean()
df['Bathroom'].fillna(br, inplace=True)
df

# %%
df.isna().sum()

# %%
df['Car'].describe

# %%
c=df['Car'].mean()
df['Car'].fillna(c, inplace=True)
df

# %%
land=df['Landsize'].mean()
df['Landsize'].fillna(land, inplace=True)
df

# %%
bu=df['BuildingArea'].mean()
df['BuildingArea'].fillna(bu, inplace=True)
df

# %%
yearb=df['YearBuilt'].median()
df['YearBuilt'].fillna(bu, inplace=True)
df

# %%
c_ar=df['CouncilArea'].mode()[0]
df['CouncilArea'].fillna(c_ar, inplace=True)
df

# %%
lat=df['Lattitude'].mean()
df['Lattitude'].fillna(lat, inplace=True)
df

# %%
long=df['Longtitude'].mean()
df['Longtitude'].fillna(long, inplace=True)
df

# %%
df.isna().sum()

# %%
label = LabelEncoder()
df['Regionname']=label.fit_transform(df['Regionname'])
df

# %%
df['Type']=label.fit_transform(df['Type'])
df

# %%
df['Method']=label.fit_transform(df['Method'])
df

# %%
df.drop('Address' , axis=1 , inplace=True)

# %%
df

# %%
onehot = pd.get_dummies(df , columns=['Suburb','SellerG','CouncilArea'],dtype=int)

# %%
onehot

# %%
df = pd.concat([df, onehot], axis=1)

# %%
df

# %%
df.drop(['Suburb','SellerG','CouncilArea'], axis=1, inplace=True)

# %%
df
